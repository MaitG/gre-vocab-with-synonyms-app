# %%
import requests
import bs4
import html5lib
from bs4 import BeautifulSoup

# %%
word = "sustain"
url = "https://www.google.com/search?q="+word+"&ei=spxuYvu7L7aar7wPyeGP0AI&ved=0ahUKEwj73Jv0xL73AhU2zYsBHcnwAyoQ4dUDCA4&uact=5&oq="+word+"&gs_lcp=-gNYsQxghA1oAnABeACAAZIBiAGABJIBAzAuNJgBAKABAcgBCsABAQ&sclient=gws-wiz"
print(url)
# Out:
# https://www.google.com/search?q=sustain&ei=spxuYvu7L7aar7wPyeGP0AI&ved=0ahUKEwj73Jv0xL73AhU2zYsBHcnwAyoQ4dUDCA4&uact=5&oq=sustain&gs_lcp=-gNYsQxghA1oAnABeACAAZIBiAGABJIBAzAuNJgBAKABAcgBCsABAQ&sclient=gws-wiz

# %%
url2 = "https://codewithharry.com/"

# %%
# Get the HTML
r = requests.get(url)
htmlcontent = r.content
#print(htmlcontent)

# %%
#Parse the HTML
soup = BeautifulSoup(htmlcontent,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>sustain - Google Search</title><script nonce="aBrYbRhXvwWUgVBTXj8hcg">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
# HTML Tree Traversal
title = soup.title
# Types of objects:
print(title) # 1. Tag
print(title.string) # 2. Navigable String
print(title.string.split(" ")[0])
print(type(soup)) # 3. BeautifulSoup Object
# 4. Comment
# Out:
# <title>sustain - Google Search</title>
# sustain - Google Search
# sustain
# <class 'bs4.BeautifulSoup'>

# %%
# word 
title = soup.title
def_title = title.string.split(" ")[0]
print(def_title)
# Out:
# sustain

# %%
# audio of the word
audio = soup.find_all('audio')
print(audio[0])
print(type(audio))
print(audio[0].get_text())
# Out:
# <audio src="http://ssl.gstatic.com/dictionary/static/sounds/20200429/sustain--_us_1.mp3"></audio>
# <class 'bs4.element.ResultSet'>

# %%
#print(audio.string)

# %%
# pronunciation
pronun = soup.find_all('span')
x = soup.find(class_ = '0mTIzf')
print(x)

print(pronun)
print(type(pronun))
# Out:
# None
# [<span class="V6gwVd">G</span>, <span class="iWkuvd">o</span>, <span class="cDrQ7">o</span>, <span class="V6gwVd">g</span>, <span class="ntlR9">l</span>, <span class="iWkuvd tJ3Myc">e</span>, <span class="V6gwVd">G</span>, <span class="iWkuvd">o</span>, <span class="cDrQ7">o</span>, <span class="V6gwVd">g</span>, <span class="ntlR9">l</span>, <span class="iWkuvd tJ3Myc">e</span>, <span class="OXXup">All</span>, <span class="OmTIzf"></span>, <span class="OmTIzf"></span>, <span><h3 class="zBAuLc l97dzf"><div class="BNeawe deIvCb AP7Wnd"><img alt="Learn to pronounce" class="RJI4s" data-deferred="1" id="flex_text_audio_icon_chunk" role="button" src="..." style="max-width:16px;max-height:16px" tabindex="0"/><audio src="http://ssl.gstatic.com/dictionary/static/sounds/20200429/sustain--_us_1.mp3"></audio> sus·tain</div></h3></span>, <span><div class="BNeawe tAd8D AP7Wnd">/səˈstān/</div></span>, <span class="xUrNXd UMOHqf">verb
# ...

# %%
anchors = soup.find_all('a')
print(anchors)
# Out:
# [<a href="/?sa=X&amp;ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8QOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a>, <a class="l" href="/?output=search&amp;ie=UTF-8&amp;sa=X&amp;ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8QPAgE"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a>, <a href="/search?q=sustain&amp;ie=UTF-8&amp;gbv=1&amp;sei=EaxuYt68BJ2E9PwP2aK4-Ao">here</a>, <a class="eZt8xd" href="/search?q=sustain&amp;ie=UTF-8&amp;source=lnms&amp;tbm=bks&amp;sa=X&amp;ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8Q_AUICCgB">Books</a>, <a class="eZt8xd" href="/search?q=sustain&amp;ie=UTF-8&amp;source=lnms&amp;tbm=isch&amp;sa=X&amp;ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8Q_AUICSgC">Images</a>, <a class="eZt8xd" href="/search?q=sustain&amp;ie=UTF-8&am
# ...

# %%
#print(type(pronun)) --> <class 'bs4.element.ResultSet'>
#for i in len(pronun):
#print(pronun[0]['class'])
#len(pronun)
for i in range(len(pronun)):
  if pronun[i].has_attr( "class" ):
    #print(pronun[i]['class'])
    if pronun[i]['class'] == ['xUrNXd', 'UMOHqf']:
      #print(pronun[i])
      print(pronun[i].get_text())
      #print(pronun[i].children) <list_iterator object at 0x7f9ea983bf90>
      #print(pronun[i].contents) ['"this thought had sustained him throughout the years"']
# Out:
# verb
#
# "this thought had sustained him throughout the years"
# synonyms: comfort, help, assist, encourage, succor, support, give strength to, be a source of strength to, be a tower of strength to, buoy up, carry, cheer up, hearten, see someone through, buck up
# "he died after sustaining severe head injuries"
# synonyms: undergo, experience, go through, suffer, endure
# "he cannot sustain a normal conversation"
# synonyms: continue, carry on, keep up, keep going, keep alive, keep in existence, keep, maintain, prolong, preserve, conserve, protract, perpetuate, bolster up, prop up, retain, extend, continuous, ongoing, steady, continual, continuing, constant, running, prolonged, persistent, nonstop, perpetual, unfaltering, unremitting, unabating, unrelenting, relentless, unrelieved, unbroken, never-ending, unending, incessant, unceasing, ceaseless, round the clock
# "the allegations of discrimination were sustained"
# ...

# %%
#class="xUrNXd UMOHqf"
class1 = ['xUrNXd', 'UMOHqf'] #example-sentences, synonyms

print(soup.find_all("span",class_=class1))
# Out:
# [<span class="xUrNXd UMOHqf">verb
# ...

# %%
class1 = ['xUrNXd', 'UMOHqf'] #example-sentences, synonyms
class2 = []

# %%
a = soup.find_all('div')
print(a)
for i in range(len(a)):
  
  if a[i].has_attr('class') == 'qexShd':
    print(a[i])
# Out:
# [<div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8QOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div>, <div class="bz1lBb"><form class="Pg70bf" id="sf"><a class="l" href="/?output=search&amp;ie=UTF-8&amp;sa=X&amp;ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8QPAgE"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a><input name="ie" type="hidden" value="ISO-8859-1"/><div class="H0PQec"><div class="sbc esbc"><input autocapitalize="none" autocomplete="off" class="noHIxc" name="q" spellcheck="false" type="text" value="sustain"/><input name="oq" type="hidden"/><input name="aqs" type="hidden"/><div class="x">×</div><div class="sc"></div></div></div><button id="qdClwb" type="submit"></button></form></d
# ...

# %%
#define different classes for:
# 1. word-title
# 2. word-audio
# 3. word-form (verb, noun etc)
#     3.1 word-definition1 to word-definitionN
#         3.1.1 List of Synonyms
#         3.1.2 List of Antonyms

# %%
#get all the links on the page
for link in anchors:
  print(link.get('href'))
# Out:
# /?sa=X&ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8QOwgC
# /?output=search&ie=UTF-8&sa=X&ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8QPAgE
# /search?q=sustain&ie=UTF-8&gbv=1&sei=EaxuYt68BJ2E9PwP2aK4-Ao
# /search?q=sustain&ie=UTF-8&source=lnms&tbm=bks&sa=X&ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8Q_AUICCgB
# /search?q=sustain&ie=UTF-8&source=lnms&tbm=isch&sa=X&ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8Q_AUICSgC
# /search?q=sustain&ie=UTF-8&source=lnms&tbm=nws&sa=X&ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8Q_AUICigD
# ...

# %%
soup.find(id="")

# %%
print(soup.find_all('span',class_=['YrbPuc']))
# Out:
# []

# %%
b = soup.find('div')
print(b.contents)
print(b.children)
# Out:
# [<a href="/?sa=X&amp;ved=0ahUKEwieiZ7I0773AhUdAp0JHVkRDq8QOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a>]
# ...

# %%
# .strings
# .stripped_strings
# .parent
# .parents --> generator
# .name 
# .previous_sibling
# .next_sibling
